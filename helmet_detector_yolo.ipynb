# %% [markdown]
# #Install Dependencies
#
# __

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-326-gec331cbd Python-3.10.12 torch-2.3.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/107.7 GB disk)

# %%
import os
import zipfile

# Define the path to the zip file
zip_file_path = '/content/drive/MyDrive/helmet detector.v2i.yolov5pytorch.zip'

# Define the extraction directory
extract_dir = '/content/drive/MyDrive/helmet_dataset'

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# List the files in the extraction directory to verify
os.listdir(extract_dir)
# Out:
# ['README.dataset.txt',
#  'README.roboflow.txt',
#  'data.yaml',
#  'test',
#  'train',
#  'valid']

# %% [markdown]
# # **training the model **

# %%
# !python train.py --data /content/yolov5/data/helmet.yaml --epochs 50 --batch-size 32 --img 516  --weights yolov5s.pt
# Out:
# 2024-06-07 13:09:43.581010: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 13:09:43.581069: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 13:09:43.582397: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/helmet_model/content/yolov5/runs/train/exp5/weights/last.pt --img 640 --conf 0.25 --source '/content/drive/MyDrive/helmet_dataset/test/images'
# Out:
# detect: weights=['/content/drive/MyDrive/helmet_model/content/yolov5/runs/train/exp5/weights/last.pt'], source=/content/drive/MyDrive/helmet_dataset/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-326-gec331cbd Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/63 /content/drive/MyDrive/helmet_dataset/test/images/BikesHelmets109_png.rf.90a56ec747ec61ad1bdda8387d1d70a3.jpg: 640x640 1 helmet, 599.2ms
# ...

# %% [markdown]
# # **model performence**
#
# > Add blockquote
#
# > [Add blockquote](https:// [link text](https://))
#
#
#
#
# ![results.png](data:image/png;base64,...)![labels_correlogram.jpg](data:image/jpeg;base64,...)![labels.jpg](data:image/jpeg;base64,...)![R_curve.png](data:image/png;base64,...)![confusion_matrix.png](data:image/png;base64,...)

# %% [markdown]
# # **downloading the weights and results**

# %%
# !zip -r /content/helmet_model.zip /content/yolov5
# Out:
# updating: content/yolov5/ (stored 0%)
# updating: content/yolov5/CITATION.cff (deflated 31%)
# updating: content/yolov5/.dockerignore (deflated 56%)
# updating: content/yolov5/requirements.txt (deflated 55%)
# updating: content/yolov5/export.py (deflated 71%)
# updating: content/yolov5/train.py (deflated 70%)
# updating: content/yolov5/pyproject.toml (deflated 59%)
# updating: content/yolov5/yolov5s.pt (deflated 9%)
# updating: content/yolov5/README.md (deflated 78%)
# updating: content/yolov5/LICENSE (deflated 66%)
# updating: content/yolov5/models/ (stored 0%)
# updating: content/yolov5/models/yolov5s.yaml (deflated 61%)
# updating: content/yolov5/models/common.py (deflated 72%)
# updating: content/yolov5/models/yolov5n.yaml (deflated 61%)
# updating: content/yolov5/models/yolo.py (deflated 67%)
# updating: content/yolov5/models/__init__.py (stored 0%)
# updating: content/yolov5/models/segment/ (stored 0%)
# updating: content/yolov5/models/segment/yolov5l-seg.yaml (deflated 61%)
# ...

# %%
from google.colab import files
files.download("/content/helmet_model.zip")

# %% [markdown]
# # **Results**
# [BikesHelmets620_png.rf.b0123779efaec7d4a11b87fd935a27ef.jpg](data:image/jpeg;base64,...)![BikesHelmets600_png.rf.85a7b37c1c6e60e3c326e75148baba78.jpg](data:image/jpeg;base64,...)![BikesHelmets626_png.rf.9056a84afb6100f2ad7dcc7a2d2c18fb.jpg](data:image/jpeg;base64,...)
